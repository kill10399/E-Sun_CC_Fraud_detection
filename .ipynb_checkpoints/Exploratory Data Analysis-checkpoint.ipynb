# %% [markdown]
# ## E-Sun Credit Card Fraud Detection task

# %%
from IPython.display import IFrame
IFrame("dataset_description.pdf", width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="dataset_description.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# import modules
# %matplotlib inline
import scipy.stats as stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_raw = pd.read_csv('train.csv')

# %%
N, N_f = train_raw.shape #1521787, 23

# %%
train_raw.sample(5)
# Out:
#          acqic   bacno    cano   conam  contp  csmcu ecfg  etymd flbmk  \
# 495694    6881  116524  120768  513.80      5      0    N      0     N
# 1290858   6189  108087  199860  248.98      5     62    N      4     N
# 1441689   6767  147812  209978  776.78      5     62    N      5     N
# 1132526   6767   31385   51230  661.24      5     62    Y      8     N
# 1285600   6716   41878   51435  751.13      5     62    Y      2     N
#
#         flg_3dsmk   ...     iterm  locdt     loctm  mcc  mchno  ovrlt  scity  \
# 495694          N   ...         0      6  122645.0  457  59333      N      0
# 1290858         N   ...         0     60  222759.0  263  98389      N   5817
# 1441689         N   ...         0     52  204324.0  191  16615      N   5817
# 1132526         Y   ...         0     30  200726.0  191  20434      N   5817
# 1285600         N   ...         0     69  111758.0  281  34368      N   5820
#
#          stocn stscd    txkey
# 495694     102     0   483267
# 1290858    102     0  1655522
# 1441689    102     0  1079240
# 1132526    102     0  1280582
# 1285600    102     0  1017774
#
# [5 rows x 23 columns]

# %%
# transter Y/N to 1/0
def to_dummy(i):
    d = {'Y':1, 'y':1, 'N':0,'n':0}
    try:
        return d[i]
    except:
        return i


isObjCol = train_raw.dtypes=='object'
isObjCol = isObjCol[isObjCol==True].index
if len(isObjCol) >0:
    train_raw[train_raw.dtypes=='object'] = train_raw.select_dtypes(['object']).applymap(lambda x:to_int(x))
    #train_raw.select_dtypes(['object']).isnull().sum()
    train_raw.select_dtypes(['object']).applymap(lambda x:to_int(x))

    train_raw[isObjCol] = train_raw.select_dtypes(['object']).applymap(lambda x:to_int(x))
# Out:
# "\ntrain_raw[train_raw.dtypes=='object'] = train_raw.select_dtypes(['object']).applymap(lambda x:to_int(x))\n#train_raw.select_dtypes(['object']).isnull().sum()\ntrain_raw.select_dtypes(['object']).applymap(lambda x:to_int(x))\nisObjCol = train_raw.dtypes=='object'\nisObjCol = isObjCol[isObjCol==True].index\ntrain_raw[isObjCol] = train_raw.select_dtypes(['object']).applymap(lambda x:to_int(x))\n"

# %%
train_raw.describe()
# Out:
#           acqic     bacno      cano     conam     contp     csmcu      ecfg  \
# count  1.52e+06  1.52e+06  1.52e+06  1.52e+06  1.52e+06  1.52e+06  1.52e+06
# mean   6.01e+03  8.21e+04  1.09e+05  6.55e+02  4.83e+00  5.38e+01  2.54e-01
# std    1.50e+03  4.74e+04  6.09e+04  4.03e+02  6.51e-01  2.07e+01  4.36e-01
# min    0.00e+00  1.00e+00  0.00e+00  0.00e+00  0.00e+00  0.00e+00  0.00e+00
# 25%    5.98e+03  4.14e+04  5.76e+04  4.37e+02  5.00e+00  6.20e+01  0.00e+00
# 50%    6.72e+03  8.19e+04  1.10e+05  5.92e+02  5.00e+00  6.20e+01  0.00e+00
# 75%    6.77e+03  1.23e+05  1.62e+05  8.07e+02  5.00e+00  6.20e+01  1.00e+00
# max    6.88e+03  1.64e+05  2.13e+05  7.21e+03  6.00e+00  7.50e+01  1.00e+00
#
#           etymd     flbmk  flg_3dsmk    ...        iterm     locdt     loctm  \
# count  1.52e+06  1.51e+06   1.51e+06    ...     1.52e+06  1.52e+06  1.52e+06
# mean   4.15e+00  3.36e-03   4.26e-02    ...     4.96e-02  4.53e+01  1.46e+05
# std    2.39e+00  5.79e-02   2.02e-01    ...     3.65e-01  2.60e+01  5.21e+04
# min    0.00e+00  0.00e+00   0.00e+00    ...     0.00e+00  1.00e+00  0.00e+00
# 25%    2.00e+00  0.00e+00   0.00e+00    ...     0.00e+00  2.30e+01  1.11e+05
# 50%    4.00e+00  0.00e+00   0.00e+00    ...     0.00e+00  4.50e+01  1.52e+05
# 75%    5.00e+00  0.00e+00   0.00e+00    ...     0.00e+00  6.80e+01  1.86e+05
# max    1.00e+01  1.00e+00   1.00e+00    ...     8.00e+00  9.00e+01  2.36e+05
#
#             mcc     mchno     ovrlt     scity     stocn     stscd     txkey
# count  1.52e+06  1.52e+06  1.52e+06  1.52e+06  1.52e+06  1.52e+06  1.52e+06
# mean   2.98e+02  5.59e+04  1.33e-02  4.76e+03  9.57e+01  2.49e-02  9.71e+05
# std    7.80e+01  3.08e+04  1.15e-01  1.98e+03  1.89e+01  2.22e-01  5.64e+05
# min    0.00e+00  0.00e+00  0.00e+00  0.00e+00  0.00e+00  0.00e+00  0.00e+00
# 25%    2.50e+02  3.38e+04  0.00e+00  3.80e+03  1.02e+02  0.00e+00  4.87e+05
# 50%    2.64e+02  5.94e+04  0.00e+00  5.82e+03  1.02e+02  0.00e+00  9.80e+05
# 75%    3.43e+02  7.92e+04  0.00e+00  5.82e+03  1.02e+02  0.00e+00  1.46e+06
# max    4.59e+02  1.03e+05  1.00e+00  6.67e+03  1.07e+02  4.00e+00  1.96e+06
#
# [8 rows x 23 columns]

# %%
# describe of txn number and avg_txn_amt
txn_num_ByAc = train_raw.groupby(['bacno','cano']).agg({'txkey':'count', 'conam':'mean'})
pd.set_option('precision', 2)
txn_num_ByAc.describe()
# Out:
#            txkey      conam
# count  129413.00  129413.00
# mean       11.76     730.77
# std        15.91     367.18
# min         1.00       0.00
# 25%         3.00     513.80
# 50%         7.00     662.07
# 75%        15.00     844.82
# max      1117.00    6728.97

# %% [markdown]
# ### Note
# fraud/non-fraud: 1501432/20355 about 74:1
#
# --> acc = <b>0.9864</b> if guess all non_fraud

# %%
fraud = train_raw.fraud_ind == 1
non_fraud = train_raw.fraud_ind == 0
train_raw.groupby(['fraud_ind']).agg({'txkey':'count'})
# Out:
#              txkey
# fraud_ind
# 0          1501432
# 1            20355

# %%
sample = train_raw.sample(round(N/5))
plt.hist(sample['conam'][sample['fraud_ind']==1], bins=75)
#plt.hist(sample['conam'][sample['fraud_ind']==0], bins=50)
# either 100 or 1000 why ?????
# Out:
# (array([555.,  23., 291.,  68.,  33.,  59., 110.,  76.,  80., 125.,  82.,
#         109., 131., 102., 116., 137.,  90., 110., 123.,  45.,  70., 395.,
#         451.,  56.,  26.,  30.,  52.,  24.,  29.,  24.,  21.,  25.,  23.,
#          21.,  29.,  25.,  18.,  27.,  15.,  15.,  29.,  11.,  10.,  22.,
#          20.,  25.,  26.,  29.,  13.,  12.,   9.,   7.,   4.,   2.,   7.,
#           6.,   2.,   3.,   5.,   1.,   4.,   0.,   2.,   0.,   2.,   0.,
#           1.,   0.,   0.,   1.,   0.,   0.,   0.,   0.,   1.]),
#  array([   0.  ,   44.71,   89.42,  134.13,  178.84,  223.55,  268.26,
#          312.97,  357.68,  402.39,  447.1 ,  491.81,  536.52,  581.23,
#          625.94,  670.65,  715.36,  760.07,  804.78,  849.49,  894.2 ,
#          938.91,  983.62, 1028.33, 1073.04, 1117.75, 1162.46, 1207.17,
#         1251.88, 1296.59, 1341.3 , 1386.01, 1430.72, 1475.43, 1520.14,
#         1564.85, 1609.56, 1654.27, 1698.98, 1743.69, 1788.4 , 1833.11,
#         1877.82, 1922.53, 1967.24, 2011.95, 2056.66, 2101.37, 2146.08,
#         2190.79, 2235.5 , 2280.21, 2324.92, 2369.63, 2414.34, 2459.05,
#         2503.76, 2548.47, 2593.18, 2637.89, 2682.6 , 2727.31, 2772.02,
#         2816.73, 2861.44, 2906.15, 2950.86, 2995.57, 3040.28, 3084.99,
#         3129.7 , 3174.41, 3219.12, 3263.83, 3308.54, 3353.25]),
#  <a list of 75 Patch objects>)

# %%
# txn time by all, fraud, non fraud
fig, axes = plt.subplots(nrows=1, ncols=3, figsize = (12,6))

axes[0].hist((train_raw.loctm/10000).round().map(int), bins=24)
axes[0].title.set_text('ALL')
axes[1].hist((train_raw.loctm[fraud]/10000).round().map(int), bins=24)
axes[1].title.set_text('Fraud')
axes[2].hist((train_raw.loctm[non_fraud]/10000).round().map(int), bins=24)
axes[2].title.set_text('Non_fraud')
plt.show()

# %% [markdown]
# ### feature correlation

# %%
corr = train_raw.corr()
plt.figure(figsize=(9,7))
heat = sns.heatmap(data=corr)
plt.title('Heatmap of Correlation')
# Out:
# Text(0.5,1,'Heatmap of Correlation')

# %% [markdown]
# #### fraud_ind have some corr with stscd?
#
# 狀態碼??

# %%
train_raw.groupby(['stscd','fraud_ind']).agg({'txkey':'count'})
# Out:
#                    txkey
# stscd fraud_ind
# 0     0          1488066
#       1            14679
# 1     0              383
#       1               25
# 2     0            12855
#       1             5651
# 3     0              108
# 4     0               20

# %% [markdown]
# ## some ideas:
# - create new cols store information by acct
# - clustering the acct by avg_txn_amt, avg_month_amt, types of spending type, acc_code.....
#
# #### even more ideas:
# - fit a dist model of txn time, txn number for every group --> give every txn a probability.

# %%
# col agg by acct
train_raw.groupby('bacno').agg({'conam':['mean','std','count']})
# Out:
# etymd       0    1        2        3        4        5   6   7        8   \
# bacno
# 1          NaN  NaN  1195.76      NaN   709.33   943.25 NaN NaN      NaN
# 2          NaN  NaN   903.66      NaN   465.96   305.88 NaN NaN      NaN
# 3          NaN  NaN   707.86      NaN   893.44   394.66 NaN NaN      NaN
# 163852  537.89  NaN   744.46      NaN      NaN      NaN NaN NaN      NaN
# 163854     NaN  NaN      NaN      NaN      NaN      NaN NaN NaN  2519.72
# 163855  513.80  NaN   465.62      NaN      NaN   708.86 NaN NaN   408.15
# 163856  513.80  NaN   554.54      NaN   235.33   396.78 NaN NaN   253.05
# 163858     NaN  NaN   465.62      NaN      NaN      NaN NaN NaN      NaN
# 163860  513.80  NaN      NaN      NaN   636.10   797.23 NaN NaN      NaN
# 163861     NaN  NaN      NaN  1395.16  1547.55      NaN NaN NaN      NaN
# 163862     NaN  NaN      NaN      NaN   617.03      NaN NaN NaN      NaN
# 163864     NaN  NaN   847.56      NaN      NaN   939.88 NaN NaN      NaN
# 163867  513.80  NaN      NaN      NaN   916.36      NaN NaN NaN      NaN
# 163870     NaN  NaN  1503.83      NaN      NaN      NaN NaN NaN      NaN
# 163874  513.80  NaN      NaN      NaN   642.27   628.14 NaN NaN  1175.13
# 163876  513.80  NaN      NaN      NaN   552.57   496.83 NaN NaN   660.99
# 163877     NaN  NaN      NaN      NaN      NaN   452.24 NaN NaN      NaN
# 163878     NaN  NaN      NaN      NaN      NaN      NaN NaN NaN      NaN
# 163879     NaN  NaN   465.62      NaN   671.59      NaN NaN NaN      NaN
# 163882  513.80  NaN   225.84      NaN   682.72   229.88 NaN NaN   193.03
# 163883     NaN  NaN      NaN      NaN   452.24   407.33 NaN NaN      NaN
# 163884     NaN  NaN      NaN      NaN   775.88   796.36 NaN NaN   965.67
#
# etymd        9   10
# bacno
# 1           NaN NaN
# 2        725.36 NaN
# 3           NaN NaN
# 4        378.81 NaN
# 7           NaN NaN
# 8           NaN NaN
# 9           NaN NaN
# 11          NaN NaN
# 15          NaN NaN
# 16          NaN NaN
# 17          NaN NaN
# 18          NaN NaN
# 20          NaN NaN
# 21          NaN NaN
# 23          NaN NaN
# 24          NaN NaN
# 26          NaN NaN
# 28          NaN NaN
# 29          NaN NaN
# 30          NaN NaN
# 33          NaN NaN
# 34          NaN NaN
# 35          NaN NaN
# 36          NaN NaN
# 37       561.06 NaN
# 40       650.82 NaN
# 41          NaN NaN
# 42          NaN NaN
# 47          NaN NaN
# 48          NaN NaN
# ...         ...  ..
# 163838      NaN NaN
# 163840  1334.91 NaN
# 163842      NaN NaN
# 163843      NaN NaN
# 163844      NaN NaN
# 163846      NaN NaN
# 163847      NaN NaN
# 163848      NaN NaN
# 163849      NaN NaN
# 163850      NaN NaN
# 163851      NaN NaN
# 163852      NaN NaN
# 163854      NaN NaN
# 163855      NaN NaN
# 163856      NaN NaN
# 163858      NaN NaN
# 163860      NaN NaN
# 163861      NaN NaN
# 163862      NaN NaN
# 163864      NaN NaN
# 163867      NaN NaN
# 163870      NaN NaN
# 163874      NaN NaN
# 163876      NaN NaN
# 163877      NaN NaN
# 163878  1285.35 NaN
# 163879      NaN NaN
# 163882      NaN NaN
# 163883      NaN NaN
# 163884      NaN NaN
#
# [95214 rows x 11 columns]
